# %%
import nltk
from nltk.tokenize import word_tokenize
from nltk.probability import FreqDist
import re

# %%
gold = """Gold is a chemical element with symbol Au (from Latin: aurum) and atomic number 79, making it one of the higher atomic number elements that occur naturally. In its purest form, it is a bright, slightly reddish yellow, dense, soft, malleable, and ductile metal. Chemically, gold is a transition metal and a group 11 element. It is one of the least reactive chemical elements and is solid under standard conditions. Gold often occurs in free elemental (native) form, as nuggets or grains, in rocks, in veins, and in alluvial deposits. It occurs in a solid solution series with the native element silver (as electrum) and also naturally alloyed with copper and palladium. Less commonly, it occurs in minerals as gold compounds, often with tellurium (gold tellurides).

Gold is resistant to most acids, though it does dissolve in aqua regia, a mixture of nitric acid and hydrochloric acid, which forms a soluble tetrachloroaurate anion. Gold is insoluble in nitric acid, which dissolves silver and base metals, a property that has long been used to refine gold and to confirm the presence of gold in metallic objects, giving rise to the term acid test. Gold also dissolves in alkaline solutions of cyanide, which are used in mining and electroplating. Gold dissolves in mercury, forming amalgam alloys, but this is not a chemical reaction.

A relatively rare element,[5][6] gold is a precious metal that has been used for coinage, jewelry, and other arts throughout recorded history. In the past, a gold standard was often implemented as a monetary policy, but gold coins ceased to be minted as a circulating currency in the 1930s, and the world gold standard was abandoned for a fiat currency system after 1971.

A total of 186,700 tonnes of gold exists above ground, as of 2015.[7] The world consumption of new gold produced is about 50% in jewelry, 40% in investments, and 10% in industry.[8] Gold's high malleability, ductility, resistance to corrosion and most other chemical reactions, and conductivity of electricity have led to its continued use in corrosion resistant electrical connectors in all types of computerized devices (its chief industrial use). Gold is also used in infrared shielding, colored-glass production, gold leafing, and tooth restoration. Certain gold salts are still used as anti-inflammatories in medicine. As of 2016, the world's largest gold producer by far was China with 450 tonnes per year"""

# %%
type(gold)
# Out:
# str

# %%
gold_word_tokenize = word_tokenize(gold)

# %%
gold_word_tokenize
# Out:
# ['Gold',
#  'is',
#  'a',
#  'chemical',
#  'element',
#  'with',
#  'symbol',
#  'Au',
#  '(',
#  'from',
#  'Latin',
#  ':',
#  'aurum',
#  ')',
#  'and',
#  'atomic',
#  'number',
#  '79',
#  ',',
#  'making',
#  'it',
#  'one',
#  'of',
#  'the',
#  'higher',
#  'atomic',
#  'number',
#  'elements',
#  'that',
#  'occur',
#  'naturally',
#  '.',
#  'In',
#  'its',
#  'purest',
#  'form',
#  ',',
#  'it',
#  'is',
#  'a',
#  'bright',
#  ',',
#  'slightly',
#  'reddish',
#  'yellow',
#  ',',
#  'dense',
#  ',',
#  'soft',
#  ',',
#  'malleable',
#  ',',
#  'and',
#  'ductile',
#  'metal',
#  '.',
#  'Chemically',
#  ',',
#  'gold',
#  'is',
#  'a',
#  'transition',
#  'metal',
#  'and',
#  'a',
#  'group',
#  '11',
#  'element',
#  '.',
#  'It',
#  'is',
#  'one',
#  'of',
#  'the',
#  'least',
#  'reactive',
#  'chemical',
#  'elements',
#  'and',
#  'is',
#  'solid',
#  'under',
#  'standard',
#  'conditions',
#  '.',
#  'Gold',
#  'often',
#  'occurs',
#  'in',
#  'free',
#  'elemental',
#  '(',
#  'native',
#  ')',
#  'form',
#  ',',
#  'as',
#  'nuggets',
#  'or',
#  'grains',
#  ',',
#  'in',
#  'rocks',
#  ',',
#  'in',
#  'veins',
#  ',',
#  'and',
#  'in',
#  'alluvial',
#  'deposits',
#  '.',
#  'It',
#  'occurs',
#  'in',
#  'a',
#  'solid',
#  'solution',
#  'series',
#  'with',
#  'the',
#  'native',
#  'element',
#  'silver',
#  '(',
#  'as',
#  'electrum',
#  ')',
#  'and',
#  'also',
#  'naturally',
#  'alloyed',
#  'with',
#  'copper',
#  'and',
#  'palladium',
#  '.',
#  'Less',
#  'commonly',
#  ',',
#  'it',
#  'occurs',
#  'in',
#  'minerals',
#  'as',
#  'gold',
#  'compounds',
#  ',',
#  'often',
#  'with',
#  'tellurium',
#  '(',
#  'gold',
#  'tellurides',
#  ')',
#  '.',
#  'Gold',
#  'is',
#  'resistant',
#  'to',
#  'most',
#  'acids',
#  ',',
#  'though',
#  'it',
#  'does',
#  'dissolve',
#  'in',
#  'aqua',
#  'regia',
#  ',',
#  'a',
#  'mixture',
#  'of',
#  'nitric',
#  'acid',
#  'and',
#  'hydrochloric',
#  'acid',
#  ',',
#  'which',
#  'forms',
#  'a',
#  'soluble',
#  'tetrachloroaurate',
#  'anion',
#  '.',
#  'Gold',
#  'is',
#  'insoluble',
#  'in',
#  'nitric',
#  'acid',
#  ',',
#  'which',
#  'dissolves',
#  'silver',
#  'and',
#  'base',
#  'metals',
#  ',',
#  'a',
#  'property',
#  'that',
#  'has',
#  'long',
#  'been',
#  'used',
#  'to',
#  'refine',
#  'gold',
#  'and',
#  'to',
#  'confirm',
#  'the',
#  'presence',
#  'of',
#  'gold',
#  'in',
#  'metallic',
#  'objects',
#  ',',
#  'giving',
#  'rise',
#  'to',
#  'the',
#  'term',
#  'acid',
#  'test',
#  '.',
#  'Gold',
#  'also',
#  'dissolves',
#  'in',
#  'alkaline',
#  'solutions',
#  'of',
#  'cyanide',
#  ',',
#  'which',
#  'are',
#  'used',
#  'in',
#  'mining',
#  'and',
#  'electroplating',
#  '.',
#  'Gold',
#  'dissolves',
#  'in',
#  'mercury',
#  ',',
#  'forming',
#  'amalgam',
#  'alloys',
#  ',',
#  'but',
#  'this',
#  'is',
#  'not',
#  'a',
#  'chemical',
#  'reaction',
#  '.',
#  'A',
#  'relatively',
#  'rare',
#  'element',
#  ',',
#  '[',
#  '5',
#  ']',
#  '[',
#  '6',
#  ']',
#  'gold',
#  'is',
#  'a',
#  'precious',
#  'metal',
#  'that',
#  'has',
#  'been',
#  'used',
#  'for',
#  'coinage',
#  ',',
#  'jewelry',
#  ',',
#  'and',
#  'other',
#  'arts',
#  'throughout',
#  'recorded',
#  'history',
#  '.',
#  'In',
#  'the',
#  'past',
#  ',',
#  'a',
#  'gold',
#  'standard',
#  'was',
#  'often',
#  'implemented',
#  'as',
#  'a',
#  'monetary',
#  'policy',
#  ',',
#  'but',
#  'gold',
#  'coins',
#  'ceased',
#  'to',
#  'be',
#  'minted',
#  'as',
#  'a',
#  'circulating',
#  'currency',
#  'in',
#  'the',
#  '1930s',
#  ',',
#  'and',
#  'the',
#  'world',
#  'gold',
#  'standard',
#  'was',
#  'abandoned',
#  'for',
#  'a',
#  'fiat',
#  'currency',
#  'system',
#  'after',
#  '1971',
#  '.',
#  'A',
#  'total',
#  'of',
#  '186,700',
#  'tonnes',
#  'of',
#  'gold',
#  'exists',
#  'above',
#  'ground',
#  ',',
#  'as',
#  'of',
#  '2015',
#  '.',
#  '[',
#  '7',
#  ']',
#  'The',
#  'world',
#  'consumption',
#  'of',
#  'new',
#  'gold',
#  'produced',
#  'is',
#  'about',
#  '50',
#  '%',
#  'in',
#  'jewelry',
#  ',',
#  '40',
#  '%',
#  'in',
#  'investments',
#  ',',
#  'and',
#  '10',
#  '%',
#  'in',
#  'industry',
#  '.',
#  '[',
#  '8',
#  ']',
#  'Gold',
#  "'s",
#  'high',
#  'malleability',
#  ',',
#  'ductility',
#  ',',
#  'resistance',
#  'to',
#  'corrosion',
#  'and',
#  'most',
#  'other',
#  'chemical',
#  'reactions',
#  ',',
#  'and',
#  'conductivity',
#  'of',
#  'electricity',
#  'have',
#  'led',
#  'to',
#  'its',
#  'continued',
#  'use',
#  'in',
#  'corrosion',
#  'resistant',
#  'electrical',
#  'connectors',
#  'in',
#  'all',
#  'types',
#  'of',
#  'computerized',
#  'devices',
#  '(',
#  'its',
#  'chief',
#  'industrial',
#  'use',
#  ')',
#  '.',
#  'Gold',
#  'is',
#  'also',
#  'used',
#  'in',
#  'infrared',
#  'shielding',
#  ',',
#  'colored-glass',
#  'production',
#  ',',
#  'gold',
#  'leafing',
#  ',',
#  'and',
#  'tooth',
#  'restoration',
#  '.',
#  'Certain',
#  'gold',
#  'salts',
#  'are',
#  'still',
#  'used',
#  'as',
#  'anti-inflammatories',
#  'in',
#  'medicine',
#  '.',
#  'As',
#  'of',
#  '2016',
#  ',',
#  'the',
#  'world',
#  "'s",
#  'largest',
#  'gold',
#  'producer',
#  'by',
#  'far',
#  'was',
#  'China',
#  'with',
#  '450',
#  'tonnes',
#  'per',
#  'year']

# %%
len(gold_word_tokenize)
# Out:
# 479

# %%
fdist = FreqDist()

# %%
fdist
# Out:
# FreqDist({})

# %%
for word in gold_word_tokenize:
    fdist[word.lower()]+=1

# %%
fdist
# Out:
# FreqDist({',': 39, 'gold': 22, 'in': 22, '.': 18, 'and': 17, 'a': 16, 'of': 12, 'is': 11, 'the': 10, 'as': 8, ...})

# %%
fdist['gold']
# Out:
# 22

# %%
len(fdist)
# Out:
# 224

# %%
fdist_top10 = fdist.most_common(10)

# %%
fdist_top10
# Out:
# [(',', 39),
#  ('gold', 22),
#  ('in', 22),
#  ('.', 18),
#  ('and', 17),
#  ('a', 16),
#  ('of', 12),
#  ('is', 11),
#  ('the', 10),
#  ('as', 8)]

# %%
from nltk.tokenize import regexp_tokenize, blankline_tokenize

# %%
len(regexp_tokenize(gold,pattern='\w+'))
# Out:
# 403

# %%
len(regexp_tokenize(gold,pattern='\d+'))
# Out:
# 16

# %%
regexp_tokenize(gold,pattern='\d+')
# Out:
# ['79',
#  '11',
#  '5',
#  '6',
#  '1930',
#  '1971',
#  '186',
#  '700',
#  '2015',
#  '7',
#  '50',
#  '40',
#  '10',
#  '8',
#  '2016',
#  '450']

# %%
len(regexp_tokenize(gold,pattern='\.'))
# Out:
# 18

# %%
len(regexp_tokenize(gold,pattern='\)'))
# Out:
# 5

# %%
gold_bl_tokenize = blankline_tokenize(gold)

# %%
gold_bl_tokenize
# Out:
# ['Gold is a chemical element with symbol Au (from Latin: aurum) and atomic number 79, making it one of the higher atomic number elements that occur naturally. In its purest form, it is a bright, slightly reddish yellow, dense, soft, malleable, and ductile metal. Chemically, gold is a transition metal and a group 11 element. It is one of the least reactive chemical elements and is solid under standard conditions. Gold often occurs in free elemental (native) form, as nuggets or grains, in rocks, in veins, and in alluvial deposits. It occurs in a solid solution series with the native element silver (as electrum) and also naturally alloyed with copper and palladium. Less commonly, it occurs in minerals as gold compounds, often with tellurium (gold tellurides).',
#  'Gold is resistant to most acids, though it does dissolve in aqua regia, a mixture of nitric acid and hydrochloric acid, which forms a soluble tetrachloroaurate anion. Gold is insoluble in nitric acid, which dissolves silver and base metals, a property that has long been used to refine gold and to confirm the presence of gold in metallic objects, giving rise to the term acid test. Gold also dissolves in alkaline solutions of cyanide, which are used in mining and electroplating. Gold dissolves in mercury, forming amalgam alloys, but this is not a chemical reaction.',
#  'A relatively rare element,[5][6] gold is a precious metal that has been used for coinage, jewelry, and other arts throughout recorded history. In the past, a gold standard was often implemented as a monetary policy, but gold coins ceased to be minted as a circulating currency in the 1930s, and the world gold standard was abandoned for a fiat currency system after 1971.',
#  "A total of 186,700 tonnes of gold exists above ground, as of 2015.[7] The world consumption of new gold produced is about 50% in jewelry, 40% in investments, and 10% in industry.[8] Gold's high malleability, ductility, resistance to corrosion and most other chemical reactions, and conductivity of electricity have led to its continued use in corrosion resistant electrical connectors in all types of computerized devices (its chief industrial use). Gold is also used in infrared shielding, colored-glass production, gold leafing, and tooth restoration. Certain gold salts are still used as anti-inflammatories in medicine. As of 2016, the world's largest gold producer by far was China with 450 tonnes per year"]

# %%
len(gold_bl_tokenize)
# Out:
# 4

# %%
gold_bl_tokenize[0]
# Out:
# 'Gold is a chemical element with symbol Au (from Latin: aurum) and atomic number 79, making it one of the higher atomic number elements that occur naturally. In its purest form, it is a bright, slightly reddish yellow, dense, soft, malleable, and ductile metal. Chemically, gold is a transition metal and a group 11 element. It is one of the least reactive chemical elements and is solid under standard conditions. Gold often occurs in free elemental (native) form, as nuggets or grains, in rocks, in veins, and in alluvial deposits. It occurs in a solid solution series with the native element silver (as electrum) and also naturally alloyed with copper and palladium. Less commonly, it occurs in minerals as gold compounds, often with tellurium (gold tellurides).'

# %%
from nltk.tokenize import sent_tokenize
gold_sent_tokenize = sent_tokenize(gold)
gold_sent_tokenize
# Out:
# ['Gold is a chemical element with symbol Au (from Latin: aurum) and atomic number 79, making it one of the higher atomic number elements that occur naturally.',
#  'In its purest form, it is a bright, slightly reddish yellow, dense, soft, malleable, and ductile metal.',
#  'Chemically, gold is a transition metal and a group 11 element.',
#  'It is one of the least reactive chemical elements and is solid under standard conditions.',
#  'Gold often occurs in free elemental (native) form, as nuggets or grains, in rocks, in veins, and in alluvial deposits.',
#  'It occurs in a solid solution series with the native element silver (as electrum) and also naturally alloyed with copper and palladium.',
#  'Less commonly, it occurs in minerals as gold compounds, often with tellurium (gold tellurides).',
#  'Gold is resistant to most acids, though it does dissolve in aqua regia, a mixture of nitric acid and hydrochloric acid, which forms a soluble tetrachloroaurate anion.',
#  'Gold is insoluble in nitric acid, which dissolves silver and base metals, a property that has long been used to refine gold and to confirm the presence of gold in metallic objects, giving rise to the term acid test.',
#  'Gold also dissolves in alkaline solutions of cyanide, which are used in mining and electroplating.',
#  'Gold dissolves in mercury, forming amalgam alloys, but this is not a chemical reaction.',
#  'A relatively rare element,[5][6] gold is a precious metal that has been used for coinage, jewelry, and other arts throughout recorded history.',
#  'In the past, a gold standard was often implemented as a monetary policy, but gold coins ceased to be minted as a circulating currency in the 1930s, and the world gold standard was abandoned for a fiat currency system after 1971.',
#  'A total of 186,700 tonnes of gold exists above ground, as of 2015.',
#  '[7] The world consumption of new gold produced is about 50% in jewelry, 40% in investments, and 10% in industry.',
#  "[8] Gold's high malleability, ductility, resistance to corrosion and most other chemical reactions, and conductivity of electricity have led to its continued use in corrosion resistant electrical connectors in all types of computerized devices (its chief industrial use).",
#  'Gold is also used in infrared shielding, colored-glass production, gold leafing, and tooth restoration.',
#  'Certain gold salts are still used as anti-inflammatories in medicine.',
#  "As of 2016, the world's largest gold producer by far was China with 450 tonnes per year"]

# %%
len(gold_sent_tokenize)
# Out:
# 19

# %%
from nltk.util import bigrams, trigrams, ngrams
string = "The Mona Lisa is a half length portrait painting by the Italian Renaissance artist Leonardo da Vinci"

# %%
mona_lisa_word_tokens = word_tokenize(string)

# %%
mona_lisa_word_tokens
# Out:
# ['The',
#  'Mona',
#  'Lisa',
#  'is',
#  'a',
#  'half',
#  'length',
#  'portrait',
#  'painting',
#  'by',
#  'the',
#  'Italian',
#  'Renaissance',
#  'artist',
#  'Leonardo',
#  'da',
#  'Vinci']

# %%
mona_lisa_bigrams = list(bigrams(mona_lisa_word_tokens))
mona_lisa_bigrams
# Out:
# [('The', 'Mona'),
#  ('Mona', 'Lisa'),
#  ('Lisa', 'is'),
#  ('is', 'a'),
#  ('a', 'half'),
#  ('half', 'length'),
#  ('length', 'portrait'),
#  ('portrait', 'painting'),
#  ('painting', 'by'),
#  ('by', 'the'),
#  ('the', 'Italian'),
#  ('Italian', 'Renaissance'),
#  ('Renaissance', 'artist'),
#  ('artist', 'Leonardo'),
#  ('Leonardo', 'da'),
#  ('da', 'Vinci')]

# %%
mona_lisa_trigrams = list(trigrams(mona_lisa_word_tokens))
mona_lisa_trigrams
# Out:
# [('The', 'Mona', 'Lisa'),
#  ('Mona', 'Lisa', 'is'),
#  ('Lisa', 'is', 'a'),
#  ('is', 'a', 'half'),
#  ('a', 'half', 'length'),
#  ('half', 'length', 'portrait'),
#  ('length', 'portrait', 'painting'),
#  ('portrait', 'painting', 'by'),
#  ('painting', 'by', 'the'),
#  ('by', 'the', 'Italian'),
#  ('the', 'Italian', 'Renaissance'),
#  ('Italian', 'Renaissance', 'artist'),
#  ('Renaissance', 'artist', 'Leonardo'),
#  ('artist', 'Leonardo', 'da'),
#  ('Leonardo', 'da', 'Vinci')]

# %%
mona_lisa_bigrams_trigrams = list(trigrams(mona_lisa_bigrams))

# %%
mona_lisa_bigrams_trigrams
# Out:
# [(('The', 'Mona'), ('Mona', 'Lisa'), ('Lisa', 'is')),
#  (('Mona', 'Lisa'), ('Lisa', 'is'), ('is', 'a')),
#  (('Lisa', 'is'), ('is', 'a'), ('a', 'half')),
#  (('is', 'a'), ('a', 'half'), ('half', 'length')),
#  (('a', 'half'), ('half', 'length'), ('length', 'portrait')),
#  (('half', 'length'), ('length', 'portrait'), ('portrait', 'painting')),
#  (('length', 'portrait'), ('portrait', 'painting'), ('painting', 'by')),
#  (('portrait', 'painting'), ('painting', 'by'), ('by', 'the')),
#  (('painting', 'by'), ('by', 'the'), ('the', 'Italian')),
#  (('by', 'the'), ('the', 'Italian'), ('Italian', 'Renaissance')),
#  (('the', 'Italian'), ('Italian', 'Renaissance'), ('Renaissance', 'artist')),
#  (('Italian', 'Renaissance'),
#   ('Renaissance', 'artist'),
#   ('artist', 'Leonardo')),
#  (('Renaissance', 'artist'), ('artist', 'Leonardo'), ('Leonardo', 'da')),
#  (('artist', 'Leonardo'), ('Leonardo', 'da'), ('da', 'Vinci'))]

# %%
mona_lisa_trigrams = list(trigrams(mona_lisa_word_tokens)),
mona_lisa_trigrams
# Out:
# ([('The', 'Mona', 'Lisa'),
#   ('Mona', 'Lisa', 'is'),
#   ('Lisa', 'is', 'a'),
#   ('is', 'a', 'half'),
#   ('a', 'half', 'length'),
#   ('half', 'length', 'portrait'),
#   ('length', 'portrait', 'painting'),
#   ('portrait', 'painting', 'by'),
#   ('painting', 'by', 'the'),
#   ('by', 'the', 'Italian'),
#   ('the', 'Italian', 'Renaissance'),
#   ('Italian', 'Renaissance', 'artist'),
#   ('Renaissance', 'artist', 'Leonardo'),
#   ('artist', 'Leonardo', 'da'),
#   ('Leonardo', 'da', 'Vinci')],)

# %%
list(nltk.ngrams(mona_lisa_word_tokens,5))
# Out:
# [('The', 'Mona', 'Lisa', 'is', 'a'),
#  ('Mona', 'Lisa', 'is', 'a', 'half'),
#  ('Lisa', 'is', 'a', 'half', 'length'),
#  ('is', 'a', 'half', 'length', 'portrait'),
#  ('a', 'half', 'length', 'portrait', 'painting'),
#  ('half', 'length', 'portrait', 'painting', 'by'),
#  ('length', 'portrait', 'painting', 'by', 'the'),
#  ('portrait', 'painting', 'by', 'the', 'Italian'),
#  ('painting', 'by', 'the', 'Italian', 'Renaissance'),
#  ('by', 'the', 'Italian', 'Renaissance', 'artist'),
#  ('the', 'Italian', 'Renaissance', 'artist', 'Leonardo'),
#  ('Italian', 'Renaissance', 'artist', 'Leonardo', 'da'),
#  ('Renaissance', 'artist', 'Leonardo', 'da', 'Vinci')]

# %%
from nltk.stem import PorterStemmer, LancasterStemmer, SnowballStemmer

# %%
pst = PorterStemmer()

# %%
pst.vowels
# Out:
# frozenset({'a', 'e', 'i', 'o', 'u'})

# %%
pst.MARTIN_EXTENSIONS
# Out:
# 'MARTIN_EXTENSIONS'

# %%
pst.pool
# Out:
# {'sky': 'sky',
#  'skies': 'sky',
#  'dying': 'die',
#  'lying': 'lie',
#  'tying': 'tie',
#  'news': 'news',
#  'innings': 'inning',
#  'inning': 'inning',
#  'outings': 'outing',
#  'outing': 'outing',
#  'cannings': 'canning',
#  'canning': 'canning',
#  'howe': 'howe',
#  'proceed': 'proceed',
#  'exceed': 'exceed',
#  'succeed': 'succeed'}

# %%
pst.stem('having')
# Out:
# 'have'

# %%
pst.stem('skies')
# Out:
# 'sky'

# %%
pst.stem('tying')
# Out:
# 'tie'

# %%
lst = LancasterStemmer()

# %%
words_to_stem=["give","Giving","giving","given","gave"]
for word in words_to_stem:
    print(word+":"+lst.stem(word))
# Out:
# give:giv
# Giving:giv
# giving:giv
# given:giv
# gave:gav

# %%
words_to_stem=["give","Give","giving","given","gave"]
for word in words_to_stem:
    print(word+":"+pst.stem(word))
# Out:
# give:give
# Give:give
# giving:give
# given:given
# gave:gave

# %%
sbst = SnowballStemmer('english')

# %%
sbst.languages
# Out:
# ('arabic',
#  'danish',
#  'dutch',
#  'english',
#  'finnish',
#  'french',
#  'german',
#  'hungarian',
#  'italian',
#  'norwegian',
#  'porter',
#  'portuguese',
#  'romanian',
#  'russian',
#  'spanish',
#  'swedish')

# %%
SnowballStemmer.mro
# Out:
# <function SnowballStemmer.mro()>

# %%
sbst.stem('having')
# Out:
# 'have'

# %%
for words in words_to_stem:
    print(words+":"+sbst.stem(words))
# Out:
# give:give
# Give:give
# giving:give
# given:given
# gave:gave

# %%
def stemms(word):
    print("Porter:"+pst.stem(word))
    print("Lancaster:"+lst.stem(word))
    print("Snowball:"+sbst.stem(word))
    return

# %%
stemms('taking')
# Out:
# Porter:take
# Lancaster:tak
# Snowball:take

# %%
stemms('data')
# Out:
# Porter:data
# Lancaster:dat
# Snowball:data

# %%
stemms('corpus')
# Out:
# Porter:corpu
# Lancaster:corp
# Snowball:corpus

# %%
stemms('curricula')
# Out:
# Porter:curricula
# Lancaster:curricul
# Snowball:curricula

# %%
stemms('curriculum')
# Out:
# Porter:curriculum
# Lancaster:curricul
# Snowball:curriculum

# %%
from nltk.stem import wordnet
from nltk.stem import WordNetLemmatizer

# %%
word_lem = WordNetLemmatizer()

# %%
word_lem.lemmatize('corpora')
# Out:
# 'corpus'

# %%
word_lem.lemmatize('curricula')
# Out:
# 'curriculum'

# %%
for words in words_to_stem:
    print(words+":"+word_lem.lemmatize(words,wordnet.NOUN))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_19504\2819117978.py in <module>
#       1 for words in words_to_stem:
# ----> 2     print(words+":"+word_lem.lemmatize(words,wordnet.NOUN))
#
# AttributeError: module 'nltk.stem.wordnet' has no attribute 'NOUN'

# %%
from nltk.corpus import stopwords

# %%
stopwords.words('english')
# Out:
# ['i',
#  'me',
#  'my',
#  'myself',
#  'we',
#  'our',
#  'ours',
#  'ourselves',
#  'you',
#  "you're",
#  "you've",
#  "you'll",
#  "you'd",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  'he',
#  'him',
#  'his',
#  'himself',
#  'she',
#  "she's",
#  'her',
#  'hers',
#  'herself',
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'they',
#  'them',
#  'their',
#  'theirs',
#  'themselves',
#  'what',
#  'which',
#  'who',
#  'whom',
#  'this',
#  'that',
#  "that'll",
#  'these',
#  'those',
#  'am',
#  'is',
#  'are',
#  'was',
#  'were',
#  'be',
#  'been',
#  'being',
#  'have',
#  'has',
#  'had',
#  'having',
#  'do',
#  'does',
#  'did',
#  'doing',
#  'a',
#  'an',
#  'the',
#  'and',
#  'but',
#  'if',
#  'or',
#  'because',
#  'as',
#  'until',
#  'while',
#  'of',
#  'at',
#  'by',
#  'for',
#  'with',
#  'about',
#  'against',
#  'between',
#  'into',
#  'through',
#  'during',
#  'before',
#  'after',
#  'above',
#  'below',
#  'to',
#  'from',
#  'up',
#  'down',
#  'in',
#  'out',
#  'on',
#  'off',
#  'over',
#  'under',
#  'again',
#  'further',
#  'then',
#  'once',
#  'here',
#  'there',
#  'when',
#  'where',
#  'why',
#  'how',
#  'all',
#  'any',
#  'both',
#  'each',
#  'few',
#  'more',
#  'most',
#  'other',
#  'some',
#  'such',
#  'no',
#  'nor',
#  'not',
#  'only',
#  'own',
#  'same',
#  'so',
#  'than',
#  'too',
#  'very',
#  's',
#  't',
#  'can',
#  'will',
#  'just',
#  'don',
#  "don't",
#  'should',
#  "should've",
#  'now',
#  'd',
#  'll',
#  'm',
#  'o',
#  're',
#  've',
#  'y',
#  'ain',
#  'aren',
#  "aren't",
#  'couldn',
#  "couldn't",
#  'didn',
#  "didn't",
#  'doesn',
#  "doesn't",
#  'hadn',
#  "hadn't",
#  'hasn',
#  "hasn't",
#  'haven',
#  "haven't",
#  'isn',
#  "isn't",
#  'ma',
#  'mightn',
#  "mightn't",
#  'mustn',
#  "mustn't",
#  'needn',
#  "needn't",
#  'shan',
#  "shan't",
#  'shouldn',
#  "shouldn't",
#  'wasn',
#  "wasn't",
#  'weren',
#  "weren't",
#  'won',
#  "won't",
#  'wouldn',
#  "wouldn't"]

# %%
len(stopwords.words('english'))
# Out:
# 179

# %%
fdist_top10
# Out:
# [(',', 39),
#  ('gold', 22),
#  ('in', 22),
#  ('.', 18),
#  ('and', 17),
#  ('a', 16),
#  ('of', 12),
#  ('is', 11),
#  ('the', 10),
#  ('as', 8)]

# %%
len(gold_word_tokenize)
# Out:
# 479

# %%
punctuation = re.compile(r'[-.?!,:;()|0-9]')

# %%
post_punctuation=[]

# %%
for words in gold_word_tokenize:
    word = punctuation.sub("",words)
    print(word)
    if len(word)>0:
        post_punctuation.append(word)
# Out:
# Gold
# is
# a
# chemical
# element
# with
# symbol
# Au
#
# from
# Latin
#
# aurum
#
# and
# atomic
# number
#
#
# making
# it
# one
# of
# the
# higher
# atomic
# number
# elements
# that
# occur
# naturally
#
# In
# its
# purest
# form
#
# it
# is
# a
# bright
#
# slightly
# reddish
# yellow
#
# dense
#
# soft
#
# malleable
#
# and
# ductile
# metal
#
# Chemically
#
# gold
# is
# a
# transition
# metal
# and
# a
# group
#
# element
#
# It
# is
# one
# of
# the
# least
# reactive
# chemical
# elements
# and
# is
# solid
# under
# standard
# conditions
#
# Gold
# often
# occurs
# in
# free
# elemental
#
# native
#
# form
#
# as
# nuggets
# or
# grains
#
# in
# rocks
#
# in
# veins
#
# and
# in
# alluvial
# deposits
#
# It
# occurs
# in
# a
# solid
# solution
# series
# with
# the
# native
# element
# silver
#
# as
# electrum
#
# and
# also
# naturally
# alloyed
# with
# copper
# and
# palladium
#
# Less
# commonly
#
# it
# occurs
# in
# minerals
# as
# gold
# compounds
#
# often
# with
# tellurium
#
# gold
# tellurides
#
#
# Gold
# is
# resistant
# to
# most
# acids
#
# though
# it
# does
# dissolve
# in
# aqua
# regia
#
# a
# mixture
# of
# nitric
# acid
# and
# hydrochloric
# acid
#
# which
# forms
# a
# soluble
# tetrachloroaurate
# anion
#
# Gold
# is
# insoluble
# in
# nitric
# acid
#
# which
# dissolves
# silver
# and
# base
# metals
#
# a
# property
# that
# has
# long
# been
# used
# to
# refine
# gold
# and
# to
# confirm
# the
# presence
# of
# gold
# in
# metallic
# objects
#
# giving
# rise
# to
# the
# term
# acid
# test
#
# Gold
# also
# dissolves
# in
# alkaline
# solutions
# of
# cyanide
#
# which
# are
# used
# in
# mining
# and
# electroplating
#
# Gold
# dissolves
# in
# mercury
#
# forming
# amalgam
# alloys
#
# but
# this
# is
# not
# a
# chemical
# reaction
#
# A
# relatively
# rare
# element
#
# [
#
# ]
# [
#
# ]
# gold
# is
# a
# precious
# metal
# that
# has
# been
# used
# for
# coinage
#
# jewelry
#
# and
# other
# arts
# throughout
# recorded
# history
#
# In
# the
# past
#
# a
# gold
# standard
# was
# often
# implemented
# as
# a
# monetary
# policy
#
# but
# gold
# coins
# ceased
# to
# be
# minted
# as
# a
# circulating
# currency
# in
# the
# s
#
# and
# the
# world
# gold
# standard
# was
# abandoned
# for
# a
# fiat
# currency
# system
# after
#
#
# A
# total
# of
#
# tonnes
# of
# gold
# exists
# above
# ground
#
# as
# of
#
#
# [
#
# ]
# The
# world
# consumption
# of
# new
# gold
# produced
# is
# about
#
# %
# in
# jewelry
#
#
# %
# in
# investments
#
# and
#
# %
# in
# industry
#
# [
#
# ]
# Gold
# 's
# high
# malleability
#
# ductility
#
# resistance
# to
# corrosion
# and
# most
# other
# chemical
# reactions
#
# and
# conductivity
# of
# electricity
# have
# led
# to
# its
# continued
# use
# in
# corrosion
# resistant
# electrical
# connectors
# in
# all
# types
# of
# computerized
# devices
#
# its
# chief
# industrial
# use
#
#
# Gold
# is
# also
# used
# in
# infrared
# shielding
#
# coloredglass
# production
#
# gold
# leafing
#
# and
# tooth
# restoration
#
# Certain
# gold
# salts
# are
# still
# used
# as
# antiinflammatories
# in
# medicine
#
# As
# of
#
#
# the
# world
# 's
# largest
# gold
# producer
# by
# far
# was
# China
# with
#
# tonnes
# per
# year

# %%
post_punctuation
# Out:
# ['Gold',
#  'is',
#  'a',
#  'chemical',
#  'element',
#  'with',
#  'symbol',
#  'Au',
#  'from',
#  'Latin',
#  'aurum',
#  'and',
#  'atomic',
#  'number',
#  'making',
#  'it',
#  'one',
#  'of',
#  'the',
#  'higher',
#  'atomic',
#  'number',
#  'elements',
#  'that',
#  'occur',
#  'naturally',
#  'In',
#  'its',
#  'purest',
#  'form',
#  'it',
#  'is',
#  'a',
#  'bright',
#  'slightly',
#  'reddish',
#  'yellow',
#  'dense',
#  'soft',
#  'malleable',
#  'and',
#  'ductile',
#  'metal',
#  'Chemically',
#  'gold',
#  'is',
#  'a',
#  'transition',
#  'metal',
#  'and',
#  'a',
#  'group',
#  'element',
#  'It',
#  'is',
#  'one',
#  'of',
#  'the',
#  'least',
#  'reactive',
#  'chemical',
#  'elements',
#  'and',
#  'is',
#  'solid',
#  'under',
#  'standard',
#  'conditions',
#  'Gold',
#  'often',
#  'occurs',
#  'in',
#  'free',
#  'elemental',
#  'native',
#  'form',
#  'as',
#  'nuggets',
#  'or',
#  'grains',
#  'in',
#  'rocks',
#  'in',
#  'veins',
#  'and',
#  'in',
#  'alluvial',
#  'deposits',
#  'It',
#  'occurs',
#  'in',
#  'a',
#  'solid',
#  'solution',
#  'series',
#  'with',
#  'the',
#  'native',
#  'element',
#  'silver',
#  'as',
#  'electrum',
#  'and',
#  'also',
#  'naturally',
#  'alloyed',
#  'with',
#  'copper',
#  'and',
#  'palladium',
#  'Less',
#  'commonly',
#  'it',
#  'occurs',
#  'in',
#  'minerals',
#  'as',
#  'gold',
#  'compounds',
#  'often',
#  'with',
#  'tellurium',
#  'gold',
#  'tellurides',
#  'Gold',
#  'is',
#  'resistant',
#  'to',
#  'most',
#  'acids',
#  'though',
#  'it',
#  'does',
#  'dissolve',
#  'in',
#  'aqua',
#  'regia',
#  'a',
#  'mixture',
#  'of',
#  'nitric',
#  'acid',
#  'and',
#  'hydrochloric',
#  'acid',
#  'which',
#  'forms',
#  'a',
#  'soluble',
#  'tetrachloroaurate',
#  'anion',
#  'Gold',
#  'is',
#  'insoluble',
#  'in',
#  'nitric',
#  'acid',
#  'which',
#  'dissolves',
#  'silver',
#  'and',
#  'base',
#  'metals',
#  'a',
#  'property',
#  'that',
#  'has',
#  'long',
#  'been',
#  'used',
#  'to',
#  'refine',
#  'gold',
#  'and',
#  'to',
#  'confirm',
#  'the',
#  'presence',
#  'of',
#  'gold',
#  'in',
#  'metallic',
#  'objects',
#  'giving',
#  'rise',
#  'to',
#  'the',
#  'term',
#  'acid',
#  'test',
#  'Gold',
#  'also',
#  'dissolves',
#  'in',
#  'alkaline',
#  'solutions',
#  'of',
#  'cyanide',
#  'which',
#  'are',
#  'used',
#  'in',
#  'mining',
#  'and',
#  'electroplating',
#  'Gold',
#  'dissolves',
#  'in',
#  'mercury',
#  'forming',
#  'amalgam',
#  'alloys',
#  'but',
#  'this',
#  'is',
#  'not',
#  'a',
#  'chemical',
#  'reaction',
#  'A',
#  'relatively',
#  'rare',
#  'element',
#  '[',
#  ']',
#  '[',
#  ']',
#  'gold',
#  'is',
#  'a',
#  'precious',
#  'metal',
#  'that',
#  'has',
#  'been',
#  'used',
#  'for',
#  'coinage',
#  'jewelry',
#  'and',
#  'other',
#  'arts',
#  'throughout',
#  'recorded',
#  'history',
#  'In',
#  'the',
#  'past',
#  'a',
#  'gold',
#  'standard',
#  'was',
#  'often',
#  'implemented',
#  'as',
#  'a',
#  'monetary',
#  'policy',
#  'but',
#  'gold',
#  'coins',
#  'ceased',
#  'to',
#  'be',
#  'minted',
#  'as',
#  'a',
#  'circulating',
#  'currency',
#  'in',
#  'the',
#  's',
#  'and',
#  'the',
#  'world',
#  'gold',
#  'standard',
#  'was',
#  'abandoned',
#  'for',
#  'a',
#  'fiat',
#  'currency',
#  'system',
#  'after',
#  'A',
#  'total',
#  'of',
#  'tonnes',
#  'of',
#  'gold',
#  'exists',
#  'above',
#  'ground',
#  'as',
#  'of',
#  '[',
#  ']',
#  'The',
#  'world',
#  'consumption',
#  'of',
#  'new',
#  'gold',
#  'produced',
#  'is',
#  'about',
#  '%',
#  'in',
#  'jewelry',
#  '%',
#  'in',
#  'investments',
#  'and',
#  '%',
#  'in',
#  'industry',
#  '[',
#  ']',
#  'Gold',
#  "'s",
#  'high',
#  'malleability',
#  'ductility',
#  'resistance',
#  'to',
#  'corrosion',
#  'and',
#  'most',
#  'other',
#  'chemical',
#  'reactions',
#  'and',
#  'conductivity',
#  'of',
#  'electricity',
#  'have',
#  'led',
#  'to',
#  'its',
#  'continued',
#  'use',
#  'in',
#  'corrosion',
#  'resistant',
#  'electrical',
#  'connectors',
#  'in',
#  'all',
#  'types',
#  'of',
#  'computerized',
#  'devices',
#  'its',
#  'chief',
#  'industrial',
#  'use',
#  'Gold',
#  'is',
#  'also',
#  'used',
#  'in',
#  'infrared',
#  'shielding',
#  'coloredglass',
#  'production',
#  'gold',
#  'leafing',
#  'and',
#  'tooth',
#  'restoration',
#  'Certain',
#  'gold',
#  'salts',
#  'are',
#  'still',
#  'used',
#  'as',
#  'antiinflammatories',
#  'in',
#  'medicine',
#  'As',
#  'of',
#  'the',
#  'world',
#  "'s",
#  'largest',
#  'gold',
#  'producer',
#  'by',
#  'far',
#  'was',
#  'China',
#  'with',
#  'tonnes',
#  'per',
#  'year']

# %%
len(post_punctuation)
# Out:
# 397

# %%
post_stop_words=[]

# %%
stp_words = stopwords.words('english')
stp_words
# Out:
# ['i',
#  'me',
#  'my',
#  'myself',
#  'we',
#  'our',
#  'ours',
#  'ourselves',
#  'you',
#  "you're",
#  "you've",
#  "you'll",
#  "you'd",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  'he',
#  'him',
#  'his',
#  'himself',
#  'she',
#  "she's",
#  'her',
#  'hers',
#  'herself',
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'they',
#  'them',
#  'their',
#  'theirs',
#  'themselves',
#  'what',
#  'which',
#  'who',
#  'whom',
#  'this',
#  'that',
#  "that'll",
#  'these',
#  'those',
#  'am',
#  'is',
#  'are',
#  'was',
#  'were',
#  'be',
#  'been',
#  'being',
#  'have',
#  'has',
#  'had',
#  'having',
#  'do',
#  'does',
#  'did',
#  'doing',
#  'a',
#  'an',
#  'the',
#  'and',
#  'but',
#  'if',
#  'or',
#  'because',
#  'as',
#  'until',
#  'while',
#  'of',
#  'at',
#  'by',
#  'for',
#  'with',
#  'about',
#  'against',
#  'between',
#  'into',
#  'through',
#  'during',
#  'before',
#  'after',
#  'above',
#  'below',
#  'to',
#  'from',
#  'up',
#  'down',
#  'in',
#  'out',
#  'on',
#  'off',
#  'over',
#  'under',
#  'again',
#  'further',
#  'then',
#  'once',
#  'here',
#  'there',
#  'when',
#  'where',
#  'why',
#  'how',
#  'all',
#  'any',
#  'both',
#  'each',
#  'few',
#  'more',
#  'most',
#  'other',
#  'some',
#  'such',
#  'no',
#  'nor',
#  'not',
#  'only',
#  'own',
#  'same',
#  'so',
#  'than',
#  'too',
#  'very',
#  's',
#  't',
#  'can',
#  'will',
#  'just',
#  'don',
#  "don't",
#  'should',
#  "should've",
#  'now',
#  'd',
#  'll',
#  'm',
#  'o',
#  're',
#  've',
#  'y',
#  'ain',
#  'aren',
#  "aren't",
#  'couldn',
#  "couldn't",
#  'didn',
#  "didn't",
#  'doesn',
#  "doesn't",
#  'hadn',
#  "hadn't",
#  'hasn',
#  "hasn't",
#  'haven',
#  "haven't",
#  'isn',
#  "isn't",
#  'ma',
#  'mightn',
#  "mightn't",
#  'mustn',
#  "mustn't",
#  'needn',
#  "needn't",
#  'shan',
#  "shan't",
#  'shouldn',
#  "shouldn't",
#  'wasn',
#  "wasn't",
#  'weren',
#  "weren't",
#  'won',
#  "won't",
#  'wouldn',
#  "wouldn't"]

# %%
len(stp_words)
# Out:
# 179

# %%
for words in post_punctuation:
    words = words.lower()
    if words not in stp_words:
        post_stop_words.append(words)

# %%
len(post_stop_words)
# Out:
# 243

# %%
fdist2 = FreqDist()

# %%
for word in post_stop_words:
    fdist2[word]+=1

# %%
len(fdist2)
# Out:
# 170

# %%
fdist2.most_common(10)
# Out:
# [('gold', 22),
#  ('used', 5),
#  ('chemical', 4),
#  ('element', 4),
#  ('acid', 4),
#  ('[', 4),
#  (']', 4),
#  ('metal', 3),
#  ('standard', 3),
#  ('often', 3)]

# %%
fdist.most_common(10)
# Out:
# [('gold', 44),
#  (',', 39),
#  ('in', 22),
#  ('.', 18),
#  ('and', 17),
#  ('a', 16),
#  ('of', 12),
#  ('is', 11),
#  ('the', 10),
#  ('used', 10)]
